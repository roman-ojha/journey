# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from collections import defaultdict

# %%
# Step 1: Load the Data
vehicles_df = pd.read_csv('travels.csv')
reviews_df = pd.read_csv('reviews.csv')

# %%
vehicles_df.head()
# Out:
#                  vehicle_id                 travel_id departure_at  \
# 0  65dda7755e43b9d7d3e4f3f9  65dda7765e43b9d7d3e4f48e   2024-03-03
# 1  65dda7765e43b9d7d3e4f4bf  65dda7795e43b9d7d3e4f67d   2024-03-03
# 2  65dda7775e43b9d7d3e4f4e6  65dda77a5e43b9d7d3e4f6df   2024-03-03
# 3  65dda7775e43b9d7d3e4f529  65dda77a5e43b9d7d3e4f74b   2024-03-03
# 4  65dda7775e43b9d7d3e4f534  65dda77a5e43b9d7d3e4f753   2024-03-03
#
#                   from                    to
# 0  Biratnagar, Sunsari         Kerkha, Jhapa
# 1       Pokhara, Kaski        Pathri, Morong
# 2  Biratnagar, Sunsari         Kerkha, Jhapa
# 3       Pathri, Morong  Koteshowr, Kathmandu
# 4  Biratnagar, Sunsari         Kerkha, Jhapa

# %%
reviews_df.rename(columns={"id":'review_id'},inplace=True)

# %%
reviews_df.head()
# Out:
#                   review_id                vehicle_id  user_id  rating
# 0  65dda7bea276ad551e8d07b2  65dda77d5e43b9d7d3e4f977       91       5
# 1  65dda7bea276ad551e8d07b3  65dda77f5e43b9d7d3e4fa4d      196       4
# 2  65dda7bea276ad551e8d07b4  65dda7855e43b9d7d3e4fe8c      180       3
# 3  65dda7bea276ad551e8d07b5  65dda7795e43b9d7d3e4f6a7      136       4
# 4  65dda7bea276ad551e8d07b6  65dda77c5e43b9d7d3e4f87f      141       3

# %%
print(reviews_df.shape)
print(vehicles_df.shape)
# Out:
# (120000, 4)
# (103, 5)

# %%
# Step 2: Preprocess the Data
vehicles_with_reviews = pd.merge(reviews_df, vehicles_df, on='vehicle_id')

# %%
vehicles_with_reviews
# Out:
#                        review_id                vehicle_id  user_id  rating  \
# 0       65dda7bea276ad551e8d07b2  65dda77d5e43b9d7d3e4f977       91       5
# 1       65dda7bea276ad551e8d07ff  65dda77d5e43b9d7d3e4f977       54       3
# 2       65dda7bea276ad551e8d0806  65dda77d5e43b9d7d3e4f977      154       5
# 3       65dda7bea276ad551e8d090c  65dda77d5e43b9d7d3e4f977       55       3
# 4       65dda7bea276ad551e8d0926  65dda77d5e43b9d7d3e4f977      192       5
# ...                          ...                       ...      ...     ...
# 119995  65dda7c7a276ad551e8ed8b7  65dda7835e43b9d7d3e4fd25       45       3
# 119996  65dda7c7a276ad551e8ed9a8  65dda7835e43b9d7d3e4fd25       71       3
# 119997  65dda7c7a276ad551e8ed9bb  65dda7835e43b9d7d3e4fd25      147       3
# 119998  65dda7c7a276ad551e8edbcd  65dda7835e43b9d7d3e4fd25        2       3
# 119999  65dda7c7a276ad551e8edbf6  65dda7835e43b9d7d3e4fd25      140       5
#
#                        travel_id departure_at                 from  \
# 0       65dda7815e43b9d7d3e4fbe6   2024-03-03  Biratnagar, Sunsari
# 1       65dda7815e43b9d7d3e4fbe6   2024-03-03  Biratnagar, Sunsari
# 2       65dda7815e43b9d7d3e4fbe6   2024-03-03  Biratnagar, Sunsari
# 3       65dda7815e43b9d7d3e4fbe6   2024-03-03  Biratnagar, Sunsari
# 4       65dda7815e43b9d7d3e4fbe6   2024-03-03  Biratnagar, Sunsari
# ...                          ...          ...                  ...
# 119995  65dda7865e43b9d7d3e4ff17   2024-03-03       Pokhara, Kaski
# 119996  65dda7865e43b9d7d3e4ff17   2024-03-03       Pokhara, Kaski
# 119997  65dda7865e43b9d7d3e4ff17   2024-03-03       Pokhara, Kaski
# 119998  65dda7865e43b9d7d3e4ff17   2024-03-03       Pokhara, Kaski
# 119999  65dda7865e43b9d7d3e4ff17   2024-03-03       Pokhara, Kaski
#
#                     to
# 0        Kerkha, Jhapa
# 1        Kerkha, Jhapa
# 2        Kerkha, Jhapa
# 3        Kerkha, Jhapa
# 4        Kerkha, Jhapa
# ...                ...
# 119995  Pathri, Morong
# 119996  Pathri, Morong
# 119997  Pathri, Morong
# 119998  Pathri, Morong
# 119999  Pathri, Morong
#
# [120000 rows x 8 columns]

# %%
# Step 3: Filter Relevant Vehicles
def filter_vehicles(data, from_location, to_location, departure_at):
    filtered_data = data[(data['from'] == from_location) & (data['to'] == to_location) & (data['departure_at'] == departure_at)]
    return filtered_data

searched_vehicles_just_from_vehicles_dataset = filter_vehicles(vehicles_df, "Pokhara, Kaski", "Pathri, Morong", "2024-03-03")
searched_vehicles = filter_vehicles(vehicles_with_reviews, "Pokhara, Kaski", "Pathri, Morong", "2024-03-03")

# %%
searched_vehicles_just_from_vehicles_dataset
# Out:
#                   vehicle_id                 travel_id departure_at  \
# 1   65dda7765e43b9d7d3e4f4bf  65dda7795e43b9d7d3e4f67d   2024-03-03
# 6   65dda7775e43b9d7d3e4f54d  65dda77a5e43b9d7d3e4f778   2024-03-03
# 12  65dda7785e43b9d7d3e4f5cd  65dda77b5e43b9d7d3e4f82a   2024-03-03
# 14  65dda7785e43b9d7d3e4f5e1  65dda77c5e43b9d7d3e4f843   2024-03-03
# 15  65dda7785e43b9d7d3e4f610  65dda77c5e43b9d7d3e4f871   2024-03-03
# 18  65dda7795e43b9d7d3e4f661  65dda77c5e43b9d7d3e4f8d5   2024-03-03
# 21  65dda7775e43b9d7d3e4f4d3  65dda77d5e43b9d7d3e4f971   2024-03-03
# 22  65dda77a5e43b9d7d3e4f712  65dda77d5e43b9d7d3e4f988   2024-03-03
# 29  65dda7775e43b9d7d3e4f570  65dda77f5e43b9d7d3e4fa87   2024-03-03
# 38  65dda77d5e43b9d7d3e4f952  65dda7815e43b9d7d3e4fbc7   2024-03-03
# 45  65dda77e5e43b9d7d3e4f9e4  65dda7825e43b9d7d3e4fc50   2024-03-03
# 50  65dda77b5e43b9d7d3e4f7aa  65dda7825e43b9d7d3e4fcbc   2024-03-03
# 54  65dda77f5e43b9d7d3e4fade  65dda7835e43b9d7d3e4fd20   2024-03-03
# 57  65dda77c5e43b9d7d3e4f839  65dda7835e43b9d7d3e4fd57   2024-03-03
2024-03-03  Pokhara, Kaski  Pathri, Morong
# 1142    65dda7865e43b9d7d3e4ff0d   2024-03-03  Pokhara, Kaski  Pathri, Morong
# ...                          ...          ...             ...             ...
# 119995  65dda7865e43b9d7d3e4ff17   2024-03-03  Pokhara, Kaski  Pathri, Morong
# 119996  65dda7865e43b9d7d3e4ff17   2024-03-03  Pokhara, Kaski  Pathri, Morong
# 119997  65dda7865e43b9d7d3e4ff17   2024-03-03  Pokhara, Kaski  Pathri, Morong
# 119998  65dda7865e43b9d7d3e4ff17   2024-03-03  Pokhara, Kaski  Pathri, Morong
# 119999  65dda7865e43b9d7d3e4ff17   2024-03-03  Pokhara, Kaski  Pathri, Morong
#
# [24525 rows x 8 columns]

# %%
# Step 4: Generate Pivot table matrix
user_ratings = searched_vehicles.pivot_table(index='user_id', columns='vehicle_id', values='rating').fillna(0)

# %%
user_ratings
# Out:
# vehicle_id  65dda7765e43b9d7d3e4f4bf  65dda7775e43b9d7d3e4f4d3  \
# user_id
# 1                           3.333333                  3.500000
# 2                           3.000000                  3.444444
# 3                           3.285714                  3.666667
# 4                           3.384615                  3.833333
# 5                           3.333333                  4.285714
# ...                              ...                       ...
# 196                         3.250000                  4.200000
# 197                         2.600000                  3.500000
# 198                         3.000000                  3.714286
# 199                         4.000000                  3.500000
# 200                         3.500000                  4.000000
#
# vehicle_id  65dda7775e43b9d7d3e4f54d  65dda7775e43b9d7d3e4f570  \
# user_id
# 1                           2.888889                  4.000000
# 2                           3.500000                  4.500000
# 3                           4.666667                  3.400000
# 4                           3.571429                  3.166667
# 5                           2.750000                  2.500000
# ...                              ...                       ...
# 196                         2.500000                  3.333333
# 197                         3.777778                  3.857143
# 198                         3.285714                  3.600000
# 199                         2.666667                  3.555556
# 200                         3.166667                  4.166667
#
# vehicle_id  65dda7785e43b9d7d3e4f5cd  65dda7785e43b9d7d3e4f5e1  \
# user_id
# 1                           3.444444                  3.250000
# 2                           4.333333                  3.000000
# 3                           3.500000                  4.250000
# 4                           3.800000                  3.500000
# 5                           3.500000                  3.333333
# ...                              ...                       ...
# 196                         3.666667                  3.181818
# 197                         3.600000                  3.000000
# 198                         3.200000                  3.111111
# 199                         3.600000                  2.000000
# 200                         3.666667                  2.600000
#
# vehicle_id  65dda7785e43b9d7d3e4f610  65dda7795e43b9d7d3e4f661  \
# user_id
# 1                           3.400000                  3.200000
# 2                           3.777778                  3.000000
# 3                           3.666667                  3.428571
# 4                           4.666667                  3.250000
# 5                           3.500000                  4.571429
# ...                              ...                       ...
# 196                         4.000000                  3.666667
# 197                         2.888889                  4.666667
# 198                         3.000000                  3.750000
# 199                         3.800000                  3.285714
# 200                         2.833333                  2.250000
#
# vehicle_id  65dda77a5e43b9d7d3e4f712  65dda77b5e43b9d7d3e4f7aa  ...  \
# user_id                                                         ...
# 1                           4.666667                  3.000000  ...
# 2                           3.333333                  2.600000  ...
# 3                           3.333333                  4.100000  ...
# 4                           4.333333                  3.428571  ...
# 5                           3.142857                  4.000000  ...
# ...                              ...                       ...  ...
# 196                         3.000000                  3.800000  ...
# 197                         3.333333                  3.833333  ...
# 198                         3.444444                  3.400000  ...
# 199                         4.500000                  3.333333  ...
# 200                         3.000000                  3.250000  ...
#
# vehicle_id  65dda77d5e43b9d7d3e4f952  65dda77e5e43b9d7d3e4f9e4  \
# user_id
# 1                           3.750000                  3.250000
# 2                           3.600000                  3.375000
# 3                           2.833333                  3.750000
# 4                           3.428571                  4.000000
# 5                           3.500000                  3.000000
# ...                              ...                       ...
# 196                         3.000000                  4.000000
# 197                         3.000000                  3.428571
# 198                         3.400000                  4.285714
# 199                         4.250000                  3.833333
# 200                         5.000000                  3.727273
#
# vehicle_id  65dda77f5e43b9d7d3e4fa4d  65dda77f5e43b9d7d3e4fade  \
# user_id
# 1                           3.666667                  3.750000
# 2                           3.714286                  4.000000
# 3                           4.333333                  3.666667
# 4                           3.400000                  3.500000
# 5                           3.100000                  4.000000
# ...                              ...                       ...
# 196                         3.285714                  5.000000
# 197                         2.000000                  3.714286
# 198                         3.444444                  3.888889
# 199                         3.125000                  3.500000
# 200                         3.333333                  3.166667
#
# vehicle_id  65dda7805e43b9d7d3e4fb2a  65dda7835e43b9d7d3e4fd25  \
# user_id
# 1                           4.000000                  3.200000
# 2                           3.000000                  3.888889
# 3                           3.555556                  3.250000
# 4                           3.300000                  3.000000
# 5                           3.571429                  3.888889
# ...                              ...                       ...
# 196                         3.538462                  4.500000
# 197                         3.000000                  3.500000
# 198                         2.400000                  3.777778
# 199                         3.750000                  3.222222
# 200                         3.400000                  4.000000
#
# vehicle_id  65dda7845e43b9d7d3e4fd9d  65dda7845e43b9d7d3e4fdba  \
# user_id
# 1                           4.500000                  3.666667
# 2                           2.600000                  4.000000
# 3                           3.000000                  3.000000
# 4                           3.200000                  3.750000
# 5                           3.571429                  2.666667
# ...                              ...                       ...
# 196                         3.400000                  3.500000
# 197                         3.571429                  4.750000
# 198                         4.000000                  3.500000
# 199                         4.000000                  3.000000
# 200                         4.000000                  3.833333
#
# vehicle_id  65dda7855e43b9d7d3e4fe52  65dda7865e43b9d7d3e4ff06
# user_id
# 1                           3.200000                  3.500000
# 2                           3.571429                  3.545455
# 3                           3.750000                  4.000000
# 4                           4.000000                  3.666667
# 5                           3.714286                  3.500000
# ...                              ...                       ...
# 196                         4.333333                  3.833333
# 197                         2.000000                  3.250000
# 198                         4.333333                  3.000000
# 199                         3.500000                  3.615385
# 200                         3.333333                  3.714286
#
# [200 rows x 21 columns]

# %%
# Explanation: https://youtu.be/3ecNC-So0r4?t=785
# Let's say that auth user have not given rating to some vehicle and it doesn't mean that user have gave 0 start rating to it
# So we will create method which will standarized the ratings given by all the users
def standardize(row):
    # takes single rows from dataframe as argument
    # now create a new row from (original rating minus(-) mean of all the ratings & divide it by the range of ratings that the user gives)
    new_row = (row - row.mean()) / (row.max() - row.min()) 
    return new_row

ratings_std = user_ratings.apply(standardize)
ratings_std
# Out:
# vehicle_id  65dda7765e43b9d7d3e4f4bf  65dda7775e43b9d7d3e4f4d3  \
# user_id
# 1                          -0.023697                  0.002352
# 2                          -0.093872                 -0.016166
# 3                          -0.033722                  0.057908
# 4                          -0.012900                  0.113463
# 5                          -0.023697                  0.264257
# ...                              ...                       ...
# 196                        -0.041240                  0.235685
# 197                        -0.178083                  0.002352
# 198                        -0.093872                  0.073781
# 199                         0.116654                  0.002352
# 200                         0.011391                  0.169019
#
# vehicle_id  65dda7775e43b9d7d3e4f54d  65dda7775e43b9d7d3e4f570  \
# user_id
# 1                          -0.201131                  0.189809
# 2                           0.002573                  0.356475
# 3                           0.391462                 -0.010191
# 4                           0.026382                 -0.087969
# 5                          -0.247427                 -0.310191
# ...                              ...                       ...
# 196                        -0.330761                 -0.032413
# 197                         0.095165                  0.142190
# 198                        -0.068856                  0.056475
# 199                        -0.275205                  0.041661
# 200                        -0.108538                  0.245364
#
# vehicle_id  65dda7785e43b9d7d3e4f5cd  65dda7785e43b9d7d3e4f5e1  \
# user_id
# 1                          -0.003636                 -0.081120
# 2                           0.292660                 -0.164453
# 3                           0.014882                  0.252214
# 4                           0.114882                  0.002214
# 5                           0.014882                 -0.053342
# ...                              ...                       ...
# 196                         0.070438                 -0.103847
# 197                         0.048216                 -0.164453
# 198                        -0.085118                 -0.127416
# 199                         0.048216                 -0.497786
# 200                         0.070438                 -0.297786
#
# vehicle_id  65dda7785e43b9d7d3e4f610  65dda7795e43b9d7d3e4f661  \
# user_id
# 1                          -0.039153                 -0.111128
# 2                           0.086772                 -0.177795
# 3                           0.049735                 -0.034937
# 4                           0.383069                 -0.094461
# 5                          -0.005820                  0.346015
# ...                              ...                       ...
# 196                         0.160847                  0.044428
# 197                        -0.209524                  0.377761
# 198                        -0.172487                  0.072205
# 199                         0.094180                 -0.082556
# 200                        -0.228042                 -0.427795
#
# vehicle_id  65dda77a5e43b9d7d3e4f712  65dda77b5e43b9d7d3e4f7aa  ...  \
# user_id                                                         ...
# 1                           0.373670                 -0.093285  ...
# 2                          -0.070774                 -0.173285  ...
# 3                          -0.070774                  0.126715  ...
# 4                           0.262559                 -0.007570  ...
# 5                          -0.134266                  0.106715  ...
# ...                              ...                       ...  ...
# 196                        -0.181885                  0.066715  ...
# 197                        -0.070774                  0.073382  ...
# 198                        -0.033737                 -0.013285  ...
# 199                         0.318115                 -0.026618  ...
# 200                        -0.181885                 -0.043285  ...
#
# vehicle_id  65dda77d5e43b9d7d3e4f952  65dda77e5e43b9d7d3e4f9e4  \
# user_id
# 1                           0.121297                 -0.089624
# 2                           0.071297                 -0.041013
# 3                          -0.184259                  0.104820
# 4                           0.014154                  0.202042
# 5                           0.037964                 -0.186847
# ...                              ...                       ...
# 196                        -0.128703                  0.202042
# 197                        -0.128703                 -0.020180
# 198                         0.004630                  0.313153
# 199                         0.287964                  0.137227
# 200                         0.537964                  0.095982
#
# vehicle_id  65dda77f5e43b9d7d3e4fa4d  65dda77f5e43b9d7d3e4fade  \
# user_id
# 1                           0.049968                  0.078306
# 2                           0.065841                  0.161639
# 3                           0.272190                  0.050528
# 4                          -0.038921                 -0.005028
# 5                          -0.138921                  0.161639
# ...                              ...                       ...
# 196                        -0.077017                  0.494972
# 197                        -0.505588                  0.066401
# 198                        -0.024106                  0.124602
# 199                        -0.130588                 -0.005028
# 200                        -0.061143                 -0.116139
#
# vehicle_id  65dda7805e43b9d7d3e4fb2a  65dda7835e43b9d7d3e4fd25  \
# user_id
# 1                           0.167364                 -0.109431
# 2                          -0.165969                  0.136601
# 3                           0.019216                 -0.091574
# 4                          -0.065969                 -0.180859
# 5                           0.024507                  0.136601
# ...                              ...                       ...
# 196                         0.013518                  0.354855
# 197                        -0.165969                 -0.002288
# 198                        -0.365969                  0.096918
# 199                         0.084031                 -0.101494
# 200                        -0.032636                  0.176283
#
# vehicle_id  65dda7845e43b9d7d3e4fd9d  65dda7845e43b9d7d3e4fdba  \
# user_id
# 1                           0.188882                  0.039559
# 2                          -0.191118                  0.150670
# 3                          -0.111118                 -0.182663
# 4                          -0.071118                  0.067337
# 5                           0.003168                 -0.293774
# ...                              ...                       ...
# 196                        -0.031118                 -0.015997
# 197                         0.003168                  0.400670
# 198                         0.088882                 -0.015997
# 199                         0.088882                 -0.182663
# 200                         0.088882                  0.095114
#
# vehicle_id  65dda7855e43b9d7d3e4fe52  65dda7865e43b9d7d3e4ff06
# user_id
# 1                          -0.091604                  0.001961
# 2                           0.032206                  0.017112
# 3                           0.091729                  0.168627
# 4                           0.175063                  0.057516
# 5                           0.079825                  0.001961
# ...                              ...                       ...
# 196                         0.286174                  0.113072
# 197                        -0.491604                 -0.081373
# 198                         0.286174                 -0.164706
# 199                         0.008396                  0.040422
# 200                        -0.047160                  0.073389
#
# [200 rows x 21 columns]

# %%
# Step 4: Compute User to User Similarities
# Cosine similaritis over here will calculate over row wise means User to User 
similarity_matrix = cosine_similarity(ratings_std) 

# or if you wanted you can do Vehicles to Vehicles similarites for that you have to transpose
vehicles_similarity_matrix = cosine_similarity(ratings_std.T)

# %%
similarity_matrix.shape
# Out:
# (200, 200)

# %%
similarity_matrix
# Out:
# array([[ 1.        , -0.0038642 , -0.49353057, ..., -0.28880222,
#          0.44279282,  0.23348864],
#        [-0.0038642 ,  1.        , -0.02586267, ...,  0.21382942,
#          0.11679966,  0.40527538],
#        [-0.49353057, -0.02586267,  1.        , ..., -0.00606295,
#         -0.42712549, -0.3895902 ],
#        ...,
#        [-0.28880222,  0.21382942, -0.00606295, ...,  1.        ,
#          0.15455422,  0.15279719],
#        [ 0.44279282,  0.11679966, -0.42712549, ...,  0.15455422,
#          1.        ,  0.39213775],
#        [ 0.23348864,  0.40527538, -0.3895902 , ...,  0.15279719,
#          0.39213775,  1.        ]])

# %%
vehicles_similarity_matrix.shape
# Out:
# (21, 21)

# %%
vehicles_similarity_matrix
# Out:
# array([[ 1.00000000e+00, -2.39816086e-02, -9.17330838e-02,
#         -1.48229999e-02, -1.39182974e-01,  6.02381005e-02,
#          2.81824250e-02,  9.08312786e-03, -4.43892328e-02,
#          1.62398957e-02, -3.49024730e-02,  1.60441268e-01,
#         -6.02939107e-02, -3.99517681e-02,  2.96227533e-03,
#          7.61768784e-02, -7.51750907e-02, -1.99813424e-02,
#          4.47399802e-02,  7.76452475e-02,  2.92268831e-02],
#         -1.28242754e-01,  8.78164897e-02, -1.10642498e-01,
#          5.99856876e-02, -4.99126796e-02,  1.00000000e+00]])

# %%
# Creating dataframe out of numpy array from vehicles_similarity_matrix so that we can use mor easily
vehicles_similarity_matrix_df = pd.DataFrame(vehicles_similarity_matrix, index=ratings_std.columns, columns=ratings_std.columns)
vehicles_similarity_matrix_df
# Here '65dda7765e43b9d7d3e4f4bf' similar to '65dda7765e43b9d7d3e4f4bf' with 100%
# '65dda7765e43b9d7d3e4f4bf' similar to '65dda7775e43b9d7d3e4f4d3' with 97%
# Explanation: https://youtu.be/3ecNC-So0r4?t=1072
# Out:
# vehicle_id                65dda7765e43b9d7d3e4f4bf  65dda7775e43b9d7d3e4f4d3  \
# vehicle_id
# 65dda7765e43b9d7d3e4f4bf                  1.000000                 -0.023982
# 65dda7775e43b9d7d3e4f4d3                 -0.023982                  1.000000
# 65dda7775e43b9d7d3e4f54d                 -0.091733                 -0.070295
# 65dda7775e43b9d7d3e4f570                 -0.014823                 -0.044604
# 65dda7785e43b9d7d3e4f5cd                 -0.139183                 -0.114281
# 65dda7785e43b9d7d3e4f5e1                  0.060238                  0.160294
# 65dda7785e43b9d7d3e4f610                  0.028182                  0.013501
# 65dda7795e43b9d7d3e4f661                  0.009083                 -0.153424
# 65dda77a5e43b9d7d3e4f712                 -0.044389                 -0.079447
# 65dda77b5e43b9d7d3e4f7aa                  0.016240                 -0.021190
# 65dda77c5e43b9d7d3e4f839                 -0.034902                 -0.019461
# 65dda77d5e43b9d7d3e4f952                  0.160441                 -0.026342
# 65dda77e5e43b9d7d3e4f9e4                 -0.060294                 -0.029607
# 65dda77f5e43b9d7d3e4fa4d                 -0.039952                 -0.018865
# 65dda77f5e43b9d7d3e4fade                  0.002962                  0.130918
# 65dda7805e43b9d7d3e4fb2a                  0.076177                 -0.028471
# 65dda7835e43b9d7d3e4fd25                 -0.075175                  0.089011
# 65dda7845e43b9d7d3e4fd9d                 -0.019981                  0.065964
# 65dda7845e43b9d7d3e4fdba                  0.044740                 -0.026688
# 65dda7855e43b9d7d3e4fe52                  0.077645                  0.029571
# 65dda7865e43b9d7d3e4ff06                  0.029227                  0.064232
#
# vehicle_id                65dda7775e43b9d7d3e4f54d  65dda7775e43b9d7d3e4f570  \
# vehicle_id
# 65dda7765e43b9d7d3e4f4bf                 -0.091733                 -0.014823
# 65dda7775e43b9d7d3e4f4d3                 -0.070295                 -0.044604
# 65dda7775e43b9d7d3e4f54d                  1.000000                 -0.074171
# 65dda7775e43b9d7d3e4f570                 -0.074171                  1.000000
# 65dda7785e43b9d7d3e4f5cd                  0.053976                 -0.033157
# 65dda7785e43b9d7d3e4f5e1                  0.085909                  0.097811
# 65dda7785e43b9d7d3e4f610                 -0.035613                  0.013773
# 65dda7795e43b9d7d3e4f661                 -0.147358                  0.030333
# 65dda77a5e43b9d7d3e4f712                  0.034101                 -0.024839
# 65dda77b5e43b9d7d3e4f7aa                 -0.100000                 -0.069453
# 65dda7795e43b9d7d3e4f661                  0.032110                 -0.021280
# 65dda77a5e43b9d7d3e4f712                 -0.085613                  0.007188
# 65dda77b5e43b9d7d3e4f7aa                 -0.085574                 -0.122476
# 65dda77c5e43b9d7d3e4f839                  0.101995                  0.054232
# 65dda77d5e43b9d7d3e4f952                 -0.159481                 -0.110104
# 65dda77e5e43b9d7d3e4f9e4                  0.130165                 -0.097071
# 65dda77f5e43b9d7d3e4fa4d                  0.037326                  0.000803
# 65dda77f5e43b9d7d3e4fade                 -0.027443                 -0.029502
# 65dda7805e43b9d7d3e4fb2a                  0.050167                  0.056146
# 65dda7835e43b9d7d3e4fd25                 -0.032334                  0.037088
# 65dda7845e43b9d7d3e4fd9d                  0.051177                 -0.033538
# 65dda7845e43b9d7d3e4fdba                  1.000000                  0.060806
# 65dda7855e43b9d7d3e4fe52                  0.060806                  1.000000
# 65dda7865e43b9d7d3e4ff06                  0.059986                 -0.049913
#
# vehicle_id                65dda7865e43b9d7d3e4ff06
# vehicle_id
# 65dda7765e43b9d7d3e4f4bf                  0.029227
# 65dda7775e43b9d7d3e4f4d3                  0.064232
# 65dda7775e43b9d7d3e4f54d                 -0.020774
# 65dda7775e43b9d7d3e4f570                 -0.087763
# 65dda7785e43b9d7d3e4f5cd                  0.088088
# 65dda7785e43b9d7d3e4f5e1                  0.112087
# 65dda7785e43b9d7d3e4f610                 -0.024929
# 65dda7795e43b9d7d3e4f661                 -0.047182
# 65dda77a5e43b9d7d3e4f712                  0.041671
# 65dda77b5e43b9d7d3e4f7aa                  0.155481
# 65dda77c5e43b9d7d3e4f839                  0.058807
# 65dda77d5e43b9d7d3e4f952                 -0.059467
# 65dda77e5e43b9d7d3e4f9e4                  0.065275
# 65dda77f5e43b9d7d3e4fa4d                 -0.124163
# 65dda77f5e43b9d7d3e4fade                 -0.065732
# 65dda7805e43b9d7d3e4fb2a                 -0.128243
# 65dda7835e43b9d7d3e4fd25                  0.087816
# 65dda7845e43b9d7d3e4fd9d                 -0.110642
# 65dda7845e43b9d7d3e4fdba                  0.059986
# 65dda7855e43b9d7d3e4fe52                 -0.049913
# 65dda7865e43b9d7d3e4ff06                  1.000000
#
# [21 rows x 21 columns]

# %%
# NOTE: bellow here are all the code explanation that is done on 'get_recommendations' function
# filters the DataFrame searched_vehicles to get only the rows where the user_id matches the given user_id 8. It extracts all reviews made by the user.
user_id = 8
user_reviews = searched_vehicles[searched_vehicles['user_id'] == user_id]
user_reviews
# Out:
#                        review_id                vehicle_id  user_id  rating  \
# 1150    65dda7bea276ad551e8d0b99  65dda77f5e43b9d7d3e4fa4d        8       3
# 1304    65dda7bea276ad551e8d49d7  65dda77f5e43b9d7d3e4fa4d        8       3
# 1326    65dda7bea276ad551e8d531d  65dda77f5e43b9d7d3e4fa4d        8       2
# 1977    65dda7c5a276ad551e8e658a  65dda77f5e43b9d7d3e4fa4d        8       2
# 2129    65dda7c5a276ad551e8ea126  65dda77f5e43b9d7d3e4fa4d        8       3
# ...                          ...                       ...      ...     ...
# 119070  65dda7bea276ad551e8d71d4  65dda7835e43b9d7d3e4fd25        8       3
# 119127  65dda7c0a276ad551e8d899d  65dda7835e43b9d7d3e4fd25        8       5
# 119320  65dda7c0a276ad551e8dd654  65dda7835e43b9d7d3e4fd25        8       2
# 119392  65dda7c3a276ad551e8dedfc  65dda7835e43b9d7d3e4fd25        8       4
# 119586  65dda7c3a276ad551e8e3d65  65dda7835e43b9d7d3e4fd25        8       3
#
#                        travel_id departure_at            from              to
# 1150    65dda7865e43b9d7d3e4ff0d   2024-03-03  Pokhara, Kaski  Pathri, Morong
# 1304    65dda7865e43b9d7d3e4ff0d   2024-03-03  Pokhara, Kaski  Pathri, Morong
# 1326    65dda7865e43b9d7d3e4ff0d   2024-03-03  Pokhara, Kaski  Pathri, Morong
# 1977    65dda7865e43b9d7d3e4ff0d   2024-03-03  Pokhara, Kaski  Pathri, Morong
# 2129    65dda7865e43b9d7d3e4ff0d   2024-03-03  Pokhara, Kaski  Pathri, Morong
# ...                          ...          ...             ...             ...
# 119070  65dda7865e43b9d7d3e4ff17   2024-03-03  Pokhara, Kaski  Pathri, Morong
# 119127  65dda7865e43b9d7d3e4ff17   2024-03-03  Pokhara, Kaski  Pathri, Morong
# 119320  65dda7865e43b9d7d3e4ff17   2024-03-03  Pokhara, Kaski  Pathri, Morong
# 119392  65dda7865e43b9d7d3e4ff17   2024-03-03  Pokhara, Kaski  Pathri, Morong
# 119586  65dda7865e43b9d7d3e4ff17   2024-03-03  Pokhara, Kaski  Pathri, Morong
#
# [132 rows x 8 columns]

# %%
# This line creates a Pandas Series called user_ratings. 
# It extracts the rating values from the user_reviews DataFrame and sets the vehicle_id values as the index of the Series. 
# This Series represents the ratings given by the user to different vehicles.
user_ratings = pd.Series(user_reviews.rating.values, index=user_reviews.vehicle_id.values)
# here user could have rated the same vehicle multiple times so, we will going to take an average of that
user_ratings = user_reviews.groupby('vehicle_id')['rating'].mean()
user_ratings.shape
# Out:
# (21,)

# %%
# geting round values to convert it into integer
# user_ratings = user_ratings.round().astype(int)
user_ratings
# Out:
# vehicle_id
# 65dda7765e43b9d7d3e4f4bf    3.600000
# 65dda7775e43b9d7d3e4f4d3    3.166667
# 65dda7775e43b9d7d3e4f54d    3.083333
# 65dda7775e43b9d7d3e4f570    3.000000
# 65dda7785e43b9d7d3e4f5cd    3.444444
# 65dda7785e43b9d7d3e4f5e1    4.166667
# 65dda7785e43b9d7d3e4f610    3.444444
# 65dda7795e43b9d7d3e4f661    3.285714
# 65dda77a5e43b9d7d3e4f712    3.500000
# 65dda77b5e43b9d7d3e4f7aa    3.333333
# 65dda77c5e43b9d7d3e4f839    3.888889
# 65dda77d5e43b9d7d3e4f952    4.200000
# 65dda77e5e43b9d7d3e4f9e4    4.250000
# 65dda77f5e43b9d7d3e4fa4d    2.600000
# 65dda77f5e43b9d7d3e4fade    2.500000
# 65dda7805e43b9d7d3e4fb2a    3.500000
# 65dda7835e43b9d7d3e4fd25    3.400000
# 65dda7845e43b9d7d3e4fd9d    3.600000
# 65dda7845e43b9d7d3e4fdba    3.666667
# 65dda7855e43b9d7d3e4fe52    3.500000
# 65dda7865e43b9d7d3e4ff06    3.600000
# Name: rating, dtype: float64

# %%
## Let's make recommendations
# This function taks vehicle_id & the rating that the auth user ex '8' have given on the vehicle_id on the past
def get_similar_vehicles(vehicle_id,user_rating):
    # let's get row of datafrom from 'vehicles_similarity_matrix_df' using the index 'vehicle_id' 
    # which means get row from the vehicle which user have already rated
    similar_score = vehicles_similarity_matrix_df[vehicle_id]
    # Now scale it by the rating that the user have given for that particular vehicle
#     similar_score = similar_score*user_rating
#     now arranging it in decending order
    similar_score = similar_score*(user_rating-2.5) # explanation is bellow next cell from this cell
    similar_score = similar_score.sort_values(ascending=False)
    # This method will return a similarity score for all the vehicles that is similar to the given vehicle 'vehicle_id'
    return similar_score

# %%
# Testing for the first user rated vehicle
first_vehicle_id = user_ratings.index[0]
first_vehicle_rating = user_ratings.iloc[0]


get_similar_vehicles(first_vehicle_id, first_vehicle_rating)
# Let's say that user give rating 1 to vehicle 'first_vehicle_id' 
# Explanation: https://youtu.be/3ecNC-So0r4?t=1225
# If the user have rated the vehicles bad then we want all other similar vehicles to go down in the list
# and other vehicle that is not similar to this vehicle to come at the top of the list
# we can achieve this in above function like this:
# similar_score = similar_score*(user_rating-2.5)
get_similar_vehicles(first_vehicle_id, 1)
# Out:
# vehicle_id
# 65dda7785e43b9d7d3e4f5cd    0.208774
# 65dda7775e43b9d7d3e4f54d    0.137600
# 65dda7835e43b9d7d3e4fd25    0.112763
# 65dda77e5e43b9d7d3e4f9e4    0.090441
# 65dda77a5e43b9d7d3e4f712    0.066584
# 65dda77f5e43b9d7d3e4fa4d    0.059928
# 65dda77c5e43b9d7d3e4f839    0.052354
# 65dda7775e43b9d7d3e4f4d3    0.035972
# 65dda7845e43b9d7d3e4fd9d    0.029972
# 65dda7775e43b9d7d3e4f570    0.022234
# 65dda77f5e43b9d7d3e4fade   -0.004443
# 65dda7795e43b9d7d3e4f661   -0.013625
# 65dda77b5e43b9d7d3e4f7aa   -0.024360
# 65dda7785e43b9d7d3e4f610   -0.042274
# 65dda7865e43b9d7d3e4ff06   -0.043840
# 65dda7845e43b9d7d3e4fdba   -0.067110
# 65dda7785e43b9d7d3e4f5e1   -0.090357
# 65dda7805e43b9d7d3e4fb2a   -0.114265
# 65dda7855e43b9d7d3e4fe52   -0.116468
# 65dda77d5e43b9d7d3e4f952   -0.240662
# 65dda7765e43b9d7d3e4f4bf   -1.500000
# Name: 65dda7765e43b9d7d3e4f4bf, dtype: float64

# %%
# converting 'user_ratings' into list of touples
user_ratings_list = list(user_ratings.items())
user_ratings_list
# Out:
# [('65dda7765e43b9d7d3e4f4bf', 3.6),
#  ('65dda7775e43b9d7d3e4f4d3', 3.1666666666666665),
#  ('65dda7775e43b9d7d3e4f54d', 3.0833333333333335),
#  ('65dda7775e43b9d7d3e4f570', 3.0),
#  ('65dda7785e43b9d7d3e4f5cd', 3.4444444444444446),
#  ('65dda7785e43b9d7d3e4f5e1', 4.166666666666667),
#  ('65dda7785e43b9d7d3e4f610', 3.4444444444444446),
#  ('65dda7795e43b9d7d3e4f661', 3.2857142857142856),
#  ('65dda77a5e43b9d7d3e4f712', 3.5),
#  ('65dda77b5e43b9d7d3e4f7aa', 3.3333333333333335),
#  ('65dda77c5e43b9d7d3e4f839', 3.888888888888889),
#  ('65dda77d5e43b9d7d3e4f952', 4.2),
#  ('65dda77e5e43b9d7d3e4f9e4', 4.25),
#  ('65dda77f5e43b9d7d3e4fa4d', 2.6),
#  ('65dda77f5e43b9d7d3e4fade', 2.5),
#  ('65dda7805e43b9d7d3e4fb2a', 3.5),
#  ('65dda7835e43b9d7d3e4fd25', 3.4),
#  ('65dda7845e43b9d7d3e4fd9d', 3.6),
#  ('65dda7845e43b9d7d3e4fdba', 3.6666666666666665),
#  ('65dda7855e43b9d7d3e4fe52', 3.5),
#  ('65dda7865e43b9d7d3e4ff06', 3.6)]

# %%
# Now we now all the vehicle that auth user have rated is stored on 'user_ratings'

similar_vehicles_df = pd.DataFrame()

# Now we will going to get similarities from every vehicle that user have rated to every other vehicles
for vehicle_id, rating in user_ratings_list:
    similar_vehicles_df[vehicle_id] = get_similar_vehicles(vehicle_id, rating)
    
# Set the index to be the default integer index
similar_vehicles_df.reset_index(drop=True, inplace=True)
# Each row in this dataframe for each 'vehicle_id' that the user has rated
# And the value in each column for vehicle id is the similarity score for each row index 'vehicle_id'
# It means that every value in this dataframe are the similarity value for each vehicle that user have rated on
similar_vehicles_df
# Out:
#     65dda7765e43b9d7d3e4f4bf  65dda7775e43b9d7d3e4f4d3  \
# 0                   1.100000                 -0.015988
# 1                   0.176485                 -0.017561
# 2                   0.085410                  0.019714
# 3                   0.083795                 -0.018981
# 4                   0.066262                  0.106863
# 5                   0.049214                 -0.017792
# 6                   0.032150                  0.042821
# 7                   0.031001                  0.009001
# 8                   0.017864                 -0.014127
# 9                   0.009991                 -0.102282
# 10                  0.003259                  0.087279
# 11                 -0.016305                 -0.029736
# 12                 -0.021979                  0.043976
# 13                 -0.026380                  0.666667
# 14                 -0.038393                 -0.012974
# 15                 -0.043947                 -0.012576
# 16                 -0.048828                 -0.052965
# 17                 -0.066323                 -0.019738
# 18                 -0.082693                  0.059341
# 19                 -0.100906                 -0.046863
# 20                 -0.153101                 -0.076187
#
#     65dda7775e43b9d7d3e4f54d  65dda7775e43b9d7d3e4f570  \
# 0                  -0.053511                 -0.007411
# 1                  -0.082557                  0.055285
# 2                  -0.028251                 -0.022811
# 3                   0.062187                  0.038655
# 4                   0.050114                  0.048905
# 5                   0.012573                  0.010501
# 6                  -0.012118                 -0.043882
# 7                  -0.020774                  0.006886
# 8                  -0.058333                 -0.034726
# 9                  -0.085959                  0.015167
# 10                 -0.045362                  0.024689
# 11                 -0.043267                  0.500000
# 12                 -0.062629                 -0.008185
# 13                 -0.041005                 -0.022302
# 14                  0.029572                 -0.004997
# 15                  0.063907                 -0.011483
# 16                  0.019892                 -0.012420
# 17                  0.004786                  0.046478
# 18                  0.044152                  0.002367
# 19                  0.583333                 -0.037086
# 20                  0.031486                 -0.016578
#
#     65dda7785e43b9d7d3e4f5cd  65dda7785e43b9d7d3e4f5e1  \
# 0                  -0.131451                  0.100397
# 1                   0.043384                 -0.279927
# 2                  -0.022790                  0.032117
# 3                  -0.091503                  0.105164
# 4                  -0.104450                  1.666667
# 5                  -0.035031                 -0.117469
# 6                   0.083194                  0.186811
# 7                   0.041830                  0.098493
# 8                  -0.111742                  0.192031
# 9                  -0.019325                 -0.222062
# 10                 -0.045392                 -0.004899
# 11                 -0.031315                  0.163018
# 12                  0.062579                 -0.097425
# 13                 -0.107932                  0.267157
# 14                  0.031790                 -0.084251
# 15                  0.011547                  0.049939
# 16                  0.130118                 -0.122457
# 17                 -0.030155                 -0.025574
# 18                  0.002932                  0.001721
# 19                  0.050977                  0.143182
# 20                  0.944444                 -0.184324
#
#     65dda7785e43b9d7d3e4f610  65dda7795e43b9d7d3e4f661  \
# 0                   0.026617                  0.007137
# 1                  -0.056480                  0.032115
# 2                   0.131130                 -0.016720
# 3                  -0.043732                 -0.055698
# 4                   0.055813                 -0.104686
# 5                   0.043101                  0.025230
# 6                  -0.023544                 -0.037072
# 7                   0.944444                 -0.084279
# 8                  -0.040864                  0.020431
# 9                  -0.101305                  0.785714
# 10                 -0.040766                  0.035224
# 11                  0.013008                  0.023833
# 12                  0.074130                  0.001861
# 13                  0.012751                 -0.120547
# 14                 -0.090754                 -0.057879
# 15                 -0.000186                  0.048910
# 16                  0.063955                 -0.046073
# 17                  0.020899                 -0.002437
# 18                 -0.037835                 -0.000365
# 19                 -0.033634                 -0.115781
# 20                  0.041830                 -0.016077
#
#     65dda77a5e43b9d7d3e4f712  65dda77b5e43b9d7d3e4f7aa  ...  \
# 0                  -0.044389                  0.013533  ...
# 1                   0.066843                 -0.072488  ...
# 2                   0.007188                 -0.102063  ...
# 3                   0.059806                 -0.025881  ...
# 4                  -0.073474                  0.096016  ...
# 5                  -0.085613                 -0.071312  ...
# 6                   0.041671                  0.129567  ...
# 7                   0.067717                 -0.036057  ...
# 8                  -0.050202                  0.833333  ...
# 9                  -0.058638                  0.021670  ...
# 10                 -0.028670                  0.072750  ...
# 11                 -0.024839                 -0.057877  ...
# 12                  0.066762                  0.118023  ...
# 13                 -0.079447                 -0.017658  ...
# 14                  0.112231                  0.075630  ...
# 15                 -0.130737                 -0.091407  ...
# 16                  1.000000                 -0.041835  ...
# 17                  0.072857                 -0.052801  ...
# 18                 -0.087734                  0.022075  ...
# 19                  0.034101                 -0.083334  ...
# 20                  0.137772                 -0.098596  ...
#
#     65dda77d5e43b9d7d3e4f952  65dda77e5e43b9d7d3e4f9e4  \
# 0                   0.272750                 -0.105514
# 1                   1.700000                  0.212408
# 2                  -0.187177                 -0.169875
# 3                  -0.044236                  0.129209
# 4                  -0.285525                 -0.026853
# 5                  -0.271118                  0.227789
# 6                  -0.101094                  0.114232
# 7                  -0.101664                  0.038725
# 8                  -0.147876                 -0.110882
# 9                   0.069485                 -0.005428
# 10                 -0.027846                 -0.039157
# 11                  0.187968                  0.162672
# 12                  0.072812                 -0.170318
# 13                 -0.044781                 -0.051813
# 14                 -0.020880                 -0.113429
# 15                  0.197593                  0.013827
# 16                  0.113634                  0.127500
# 17                  0.206339                  1.750000
# 18                 -0.064950                  0.064068
# 19                 -0.240595                  0.014359
# 20                  0.078091                 -0.055876
#
#     65dda77f5e43b9d7d3e4fa4d  65dda77f5e43b9d7d3e4fade  \
# 0                  -0.003995                       0.0
# 1                   0.011623                      -0.0
# 2                   0.000080                      -0.0
# 3                  -0.001418                      -0.0
# 4                   0.002996                      -0.0
# 5                   0.003733                      -0.0
# 6                  -0.012416                      -0.0
# 7                  -0.000020                      -0.0
# 8                  -0.010969                       0.0
# 9                   0.006225                       0.0
# 10                  0.005432                       0.0
# 11                 -0.002297                       0.0
# 12                 -0.005903                      -0.0
# 13                 -0.001886                       0.0
# 14                 -0.000054                      -0.0
# 15                  0.100000                       0.0
# 16                 -0.013074                      -0.0
# 17                  0.000790                      -0.0
# 18                  0.005206                       0.0
# 19                  0.010956                      -0.0
# 20                  0.001223                      -0.0
#
#     65dda7805e43b9d7d3e4fb2a  65dda7835e43b9d7d3e4fd25  \
# 0                   0.076177                 -0.067658
# 1                  -0.026021                 -0.034385
# 2                   0.056146                  0.033380
# 3                   1.000000                 -0.005907
# 4                   0.063099                  0.000929
# 5                   0.050167                 -0.029101
# 6                  -0.128243                  0.079035
# 7                  -0.046304                 -0.036055
# 8                  -0.031057                  0.023841
# 9                  -0.070889                 -0.000418
# 10                 -0.032759                  0.067088
# 11                  0.077311                  0.004261
# 12                  0.019098                 -0.028598
# 13                 -0.028471                  0.080110
# 14                 -0.028899                 -0.043506
# 15                 -0.014182                  0.046853
# 16                  0.059806                 -0.078960
# 17                  0.073834                  0.032949
# 18                 -0.006563                  0.900000
# 19                  0.106607                  0.068120
# 20                 -0.096885                  0.002794
#
#     65dda7845e43b9d7d3e4fd9d  65dda7845e43b9d7d3e4fdba  \
# 0                  -0.021979                  0.052197
# 1                   0.047114                 -0.186062
# 2                  -0.036892                  0.070941
# 3                   0.021008                  0.058528
# 4                  -0.064300                 -0.082228
# 5                   0.056294                  1.166667
# 6                  -0.121707                  0.069983
# 7                   0.086340                  0.053242
# 8                   0.155791                 -0.099836
# 9                   0.002605                  0.037462
# 10                 -0.009272                 -0.032016
# 11                 -0.018007                  0.024503
# 12                  1.100000                  0.059706
# 13                  0.072561                 -0.031136
# 14                  0.018829                  0.118995
# 15                 -0.064931                  0.043547
# 16                  0.073438                 -0.099882
# 17                 -0.107057                  0.151859
# 18                 -0.034953                 -0.037723
# 19                 -0.118101                  0.025147
# 20                  0.072886                 -0.043274
#
#     65dda7855e43b9d7d3e4fe52  65dda7865e43b9d7d3e4ff06
# 0                   0.077645                  0.032150
# 1                  -0.110104                 -0.065414
# 2                   1.000000                 -0.054904
# 3                   0.056146                 -0.141067
# 4                   0.019270                  0.123296
# 5                   0.060806                  0.065984
# 6                  -0.049913                  1.100000
# 7                   0.138844                 -0.027422
# 8                  -0.122476                  0.171029
# 9                  -0.021280                 -0.051901
# 10                 -0.029502                 -0.072305
# 11                 -0.045623                 -0.096539
# 12                 -0.033538                 -0.121707
# 13                  0.029571                  0.070655
# 14                  0.054232                  0.064688
# 15                  0.000803                 -0.136579
# 16                  0.007188                  0.045839
# 17                 -0.097071                  0.071803
# 18                  0.037088                  0.096598
# 19                 -0.048431                 -0.022851
# 20                 -0.024131                  0.096897
#
# [21 rows x 21 columns]

# %%
# Now let's sum all the vehicle id values row wise and sort them in decending order
similar_vehicles = similar_vehicles_df.sum().sort_values(ascending=False)
similar_vehicles
# Out:
# 65dda77e5e43b9d7d3e4f9e4    2.005644
# 65dda7785e43b9d7d3e4f5e1    1.868311
# 65dda77d5e43b9d7d3e4f952    1.360929
# 65dda7845e43b9d7d3e4fdba    1.320620
# 65dda77c5e43b9d7d3e4f839    1.309666
# 65dda7865e43b9d7d3e4ff06    1.148248
# 65dda7845e43b9d7d3e4fd9d    1.109665
# 65dda7805e43b9d7d3e4fb2a    1.071969
# 65dda7765e43b9d7d3e4f4bf    1.056574
# 65dda7835e43b9d7d3e4fd25    1.014772
# 65dda77a5e43b9d7d3e4f712    1.003206
# 65dda7785e43b9d7d3e4f610    0.958578
# 65dda7855e43b9d7d3e4fe52    0.899528
# 65dda7785e43b9d7d3e4f5cd    0.671710
# 65dda77b5e43b9d7d3e4f7aa    0.631290
# 65dda7775e43b9d7d3e4f4d3    0.597891
# 65dda7775e43b9d7d3e4f570    0.527052
# 65dda7775e43b9d7d3e4f54d    0.368237
# 65dda7795e43b9d7d3e4f661    0.322840
# 65dda77f5e43b9d7d3e4fa4d    0.096232
# 65dda77f5e43b9d7d3e4fade    0.000000
# dtype: float64

# %%
recommended_vehicles = similar_vehicles.index.tolist()

# %%
recommended_vehicles
# Out:
# ['65dda77e5e43b9d7d3e4f9e4',
#  '65dda7785e43b9d7d3e4f5e1',
#  '65dda77d5e43b9d7d3e4f952',
#  '65dda7845e43b9d7d3e4fdba',
#  '65dda77c5e43b9d7d3e4f839',
#  '65dda7865e43b9d7d3e4ff06',
#  '65dda7845e43b9d7d3e4fd9d',
#  '65dda7805e43b9d7d3e4fb2a',
#  '65dda7765e43b9d7d3e4f4bf',
#  '65dda7835e43b9d7d3e4fd25',
#  '65dda77a5e43b9d7d3e4f712',
#  '65dda7785e43b9d7d3e4f610',
#  '65dda7855e43b9d7d3e4fe52',
#  '65dda7785e43b9d7d3e4f5cd',
#  '65dda77b5e43b9d7d3e4f7aa',
#  '65dda7775e43b9d7d3e4f4d3',
#  '65dda7775e43b9d7d3e4f570',
#  '65dda7775e43b9d7d3e4f54d',
#  '65dda7795e43b9d7d3e4f661',
#  '65dda77f5e43b9d7d3e4fa4d',
#  '65dda77f5e43b9d7d3e4fade']

# %%
# NOTE: Issues that we could face on Collaborative Filtering
# 1. Handling Unknown Users / Vehicles (Cold Start Problem) where we don't know any context about it for rignt now
# 2. Scalalability: Takes havy performance to perform this model
# 3. Dynamic Update: When ever we will add new vehicle or User or Rating Data Then we again have to re build this model
# For that we can create a Hybrid recommendation system to handle this challanges
# Also we can use Papularity based filtering
